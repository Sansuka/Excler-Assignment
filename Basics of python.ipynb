# %% [markdown]
# #### Exercise 1: Prime Numbers

# %% [markdown]
# ##### Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
n = int(input("Enter a Number"))
if n <= 1:
    print("Not a Prime Number")
else:
    is_prime = True
    for i in range (2,n):
        if n % 1 == 0:
            is_prime = False
            break
    if is_prime:
        print("Prime")
    else:
        print("Not a Prime Number")
# Out:
# Enter a Number 4
# Not a Prime Number

# %% [markdown]
# #### Exercise 2: Product of Random Numbers

# %% [markdown]
# ##### Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random
n1 = random.randint(1,10)
n2 = random.randint(1,10)
answer = int(input(f"What is {n1} x {n2}? "))

if answer == n1 * n2:
    print("Your answer is correct")
else:
    print("Incorrect")
    print(f"The correct anser is {n1 * n2}")
# Out:
# What is 9 x 6?  54
# Your answer is correct

# %% [markdown]
# #### Exercise 3: Squares of Even/Odd Numbers

# %% [markdown]
# ##### Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
# Even no
for n in range (100,201):
    if n % 2 == 0:
        print(f"Square of {n} = {n ** 2}")
# Out:
# Square of 100 = 10000
# Square of 102 = 10404
# Square of 104 = 10816
# Square of 106 = 11236
# Square of 108 = 11664
# Square of 110 = 12100
# Square of 112 = 12544
# Square of 114 = 12996
# Square of 116 = 13456
# Square of 118 = 13924
# Square of 120 = 14400
# Square of 122 = 14884
# Square of 124 = 15376
# Square of 126 = 15876
# Square of 128 = 16384
# Square of 130 = 16900
# Square of 132 = 17424
# Square of 134 = 17956
# Square of 136 = 18496
# Square of 138 = 19044
# Square of 140 = 19600
# Square of 142 = 20164
# Square of 144 = 20736
# Square of 146 = 21316
# Square of 148 = 21904
# Square of 150 = 22500
# Square of 152 = 23104
# Square of 154 = 23716
# Square of 156 = 24336
# Square of 158 = 24964
# Square of 160 = 25600
# Square of 162 = 26244
# Square of 164 = 26896
# Square of 166 = 27556
# Square of 168 = 28224
# Square of 170 = 28900
# Square of 172 = 29584
# Square of 174 = 30276
# Square of 176 = 30976
# Square of 178 = 31684
# Square of 180 = 32400
# Square of 182 = 33124
# Square of 184 = 33856
# Square of 186 = 34596
# Square of 188 = 35344
# Square of 190 = 36100
# Square of 192 = 36864
# Square of 194 = 37636
# Square of 196 = 38416
# Square of 198 = 39204
# Square of 200 = 40000

# %%
# Odd no
for n in range (100,201):
    if n % 2 != 0:
        print(f"Square of {n} = {n ** 2}")
# Out:
# Square of 101 = 10201
# Square of 103 = 10609
# Square of 105 = 11025
# Square of 107 = 11449
# Square of 109 = 11881
# Square of 111 = 12321
# Square of 113 = 12769
# Square of 115 = 13225
# Square of 117 = 13689
# Square of 119 = 14161
# Square of 121 = 14641
# Square of 123 = 15129
# Square of 125 = 15625
# Square of 127 = 16129
# Square of 129 = 16641
# Square of 131 = 17161
# Square of 133 = 17689
# Square of 135 = 18225
# Square of 137 = 18769
# Square of 139 = 19321
# Square of 141 = 19881
# Square of 143 = 20449
# Square of 145 = 21025
# Square of 147 = 21609
# Square of 149 = 22201
# Square of 151 = 22801
# Square of 153 = 23409
# Square of 155 = 24025
# Square of 157 = 24649
# Square of 159 = 25281
# Square of 161 = 25921
# Square of 163 = 26569
# Square of 165 = 27225
# Square of 167 = 27889
# Square of 169 = 28561
# Square of 171 = 29241
# Square of 173 = 29929
# Square of 175 = 30625
# Square of 177 = 31329
# Square of 179 = 32041
# Square of 181 = 32761
# Square of 183 = 33489
# Square of 185 = 34225
# Square of 187 = 34969
# Square of 189 = 35721
# Square of 191 = 36481
# Square of 193 = 37249
# Square of 195 = 38025
# Square of 197 = 38809
# Square of 199 = 39601

# %% [markdown]
# #### Exercise 4:

# %% [markdown]
# #### ✅ Problem Statement (Question): Hospital Billing System
# ##### A hospital charges its patients based on the following:
# - Room charges per day: ₹2,000
# - Doctor consultation fee (flat): ₹1,500
# - Lab test charges: Based on the number of tests taken. Each test costs ₹300
# - Medicine charges: Total cost of medicines provided
# - Discount: If the total bill (before discount) exceeds ₹10,000, a 10% discount is applied
# ##### Write a Python program to calculate the final bill for a patient who:
# - Stayed for 4 days
# - Had 3 lab tests
# - Had medicine charges of ₹2,400

# %%
room_days = int(input("Enter number of days: "))
lab_tests = int(input("Enter number of lab tests: "))

room_charge_per_day = 2000
doctor_fee = 1500
lab_charge_per_test = 300
medicine_charge = 2400

room_charge = room_days * room_charge_per_day
lab_charge = lab_tests * lab_charge_per_test

total = room_charge + doctor_fee + lab_charge + medicine_charge

if total > 10000:
    discount = total * 0.10
else:
    discount = 0

final_bill = total - discount

print("\n---------- Hospital Bill ----------")
print("Room Charges (₹2,000/day) :", room_charge)
print("Doctor Fee                :", doctor_fee)
print("Lab Charges (₹300/test)   :", lab_charge)
print("Medicine Charges          :", medicine_charge)
print("Total Bill                :", total)
print("Discount                  :", discount)
print("Final Bill                :", final_bill)
# Out:
# Enter number of days:  4
# Enter number of lab tests:  3
# ---------- Hospital Bill ----------
# Room Charges (₹2,000/day) : 8000
# Doctor Fee                : 1500
# Lab Charges (₹300/test)   : 900
# Medicine Charges          : 2400
# Total Bill                : 12800
# Discount                  : 1280.0
# Final Bill                : 11520.0
